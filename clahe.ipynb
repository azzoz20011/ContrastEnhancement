# %%
def calc_tile_histogram(tile, hist_size, clip_limit):
    """Compute histogram for one tile, apply clipping & redistribution."""
    hist, _ = np.histogram(tile, bins=hist_size, range=(0, hist_size))

    if clip_limit > 0:
        # clip histogram
        excess = np.maximum(hist - clip_limit, 0)
        clipped = np.sum(excess)
        hist = np.minimum(hist, clip_limit)

        # redistribute excess
        redist_batch = clipped // hist_size
        hist += redist_batch

        residual = clipped - redist_batch * hist_size
        if residual > 0:
            step = max(1, hist_size // residual)
            for i in range(0, hist_size, step):
                if residual <= 0:
                    break
                hist[i] += 1
                residual -= 1
    return hist

# %%
def calc_lut_from_hist(hist, lut_scale, hist_size, dtype):
    """Build LUT by cumulative sum of histogram."""
    lut = np.cumsum(hist) * lut_scale
    return np.clip(lut, 0, hist_size - 1).astype(dtype)

# %%
def compute_luts(src, tiles_x, tiles_y, clip_limit, hist_size, lut_scale, dtype):
    """Compute LUT for each tile."""
    h, w = src.shape
    tile_h = h // tiles_y
    tile_w = w // tiles_x

    luts = np.zeros((tiles_y, tiles_x, hist_size), dtype=dtype)

    for ty in range(tiles_y):
        for tx in range(tiles_x):
            tile = src[ty*tile_h:(ty+1)*tile_h, tx*tile_w:(tx+1)*tile_w]
            hist = calc_tile_histogram(tile, hist_size, clip_limit)
            lut = calc_lut_from_hist(hist, lut_scale, hist_size, dtype)
            luts[ty, tx] = lut
    return luts, (tile_h, tile_w)

# %%
def interpolate_apply(src, luts, tile_size, tiles_x, tiles_y, shift, dtype):
    """Apply CLAHE by bilinear interpolation between neighboring LUTs."""
    h, w = src.shape
    dst = np.zeros_like(src, dtype=dtype)
    tile_h, tile_w = tile_size

    for y in range(h):
        tyf = y / tile_h - 0.5
        ty1 = max(int(np.floor(tyf)), 0)
        ty2 = min(ty1 + 1, tiles_y - 1)
        ya = tyf - np.floor(tyf)
        ya1 = 1.0 - ya

        for x in range(w):
            txf = x / tile_w - 0.5
            tx1 = max(int(np.floor(txf)), 0)
            tx2 = min(tx1 + 1, tiles_x - 1)
            xa = txf - np.floor(txf)
            xa1 = 1.0 - xa

            val = src[y, x] >> shift

            # bilinear interpolation from 4 LUTs
            res = (
                luts[ty1, tx1, val] * xa1 * ya1 +
                luts[ty1, tx2, val] * xa  * ya1 +
                luts[ty2, tx1, val] * xa1 * ya  +
                luts[ty2, tx2, val] * xa  * ya
            )

            dst[y, x] = np.clip(round(res), 0, (1 << (16 - shift)) - 1) << shift
    return dst

# %%
def clahe(src, clip_limit=40.0, tiles_x=8, tiles_y=8):
    """Full CLAHE pipeline."""
    assert src.dtype in (np.uint8, np.uint16)

    hist_size = 256 if src.dtype == np.uint8 else 65536
    tile_size = (src.shape[0] // tiles_y, src.shape[1] // tiles_x)
    tile_area = tile_size[0] * tile_size[1]

    lut_scale = (hist_size - 1) / float(tile_area)

    if clip_limit > 0.0:
        clip_limit = max(int(clip_limit * tile_area / hist_size), 1)
    else:
        clip_limit = 0

    shift = 0  # in OpenCV code, shift can reduce bins (not used here)

    luts, tile_size = compute_luts(src, tiles_x, tiles_y, clip_limit, hist_size, lut_scale, src.dtype)
    dst = interpolate_apply(src, luts, tile_size, tiles_x, tiles_y, shift, src.dtype)
    return dst

# %%
container = av.open(FILE)

# %%
import os
import math
import av
import numpy as np
import cv2


def pad_reflect_101(img, tiles_x, tiles_y):
    """Pad so H and W are divisible by tiles grid, like BORDER_REFLECT_101."""
    h, w = img.shape
    pad_y = (tiles_y - (h % tiles_y))
    pad_x = (tiles_x - (w % tiles_x)) 
    if pad_y or pad_x:
        img = np.pad(img, ((0, pad_y), (0, pad_x)), mode='reflect')
    return img, (h, w)  # keep original size to crop back later


def clip_limit_to_count(clip_limit_ui, tile_area, hist_size):
    """OpenCV converts UI clipLimit to a per-tile count."""
    if clip_limit_ui <= 0.0:
        return 0
    count = int(clip_limit_ui * tile_area / hist_size)
    return max(count, 1)


def calc_tile_histogram(tile, hist_size, clip_count):
    """Histogram + clip + redistribute (like OpenCV's CPU path)."""
    # Fast histogram
    hist, _ = np.histogram(tile, bins=hist_size, range=(0, hist_size))

    if clip_count > 0:

        excess = np.maximum(hist - clip_count, 0)
        clipped_total = int(excess.sum())
        # clip
        hist = np.minimum(hist, clip_count)

        if clipped_total:
            # even batch
            redist_batch = clipped_total // hist_size
            hist += redist_batch
            # remainder spread
            residual = clipped_total - redist_batch * hist_size
    
            if residual > 0:
                step = max(1, hist_size // residual)
                # increment roughly uniformly
                for i in range(0, hist_size, step):
                    if residual <= 0:
                        break
                    hist[i] += 1
                    residual -= 1
    return hist


def lut_from_hist(hist, lut_scale, hist_size, dtype):
    """Cumulative sum with OpenCV-like rounding & clamp."""
    lut = np.rint(np.cumsum(hist) * lut_scale)  # round-to-nearest
    return np.clip(lut, 0, hist_size - 1).astype(dtype)


def compute_luts(src_padded, tiles_x, tiles_y, clip_count, hist_size, lut_scale, dtype):
    """Compute LUT per tile on the padded image."""
    H, W = src_padded.shape
    tile_h = H // tiles_y
    tile_w = W // tiles_x
    luts = np.empty((tiles_y, tiles_x, hist_size), dtype=dtype)

    for ty in range(tiles_y):
        y0 = ty * tile_h
        y1 = y0 + tile_h
        for tx in range(tiles_x):
            x0 = tx * tile_w
            x1 = x0 + tile_w
            tile = src_padded[y0:y1, x0:x1]
            hist = calc_tile_histogram(tile, hist_size, clip_count)
            luts[ty, tx] = lut_from_hist(hist, lut_scale, hist_size, dtype)
    return luts, (tile_h, tile_w)


def interpolate_apply(src_padded, luts, tile_size, tiles_x, tiles_y, shift, out_dtype):
    """Bilinear interpolation of 4 neighboring tile LUTs, like OpenCV."""
    H, W = src_padded.shape
    tile_h, tile_w = tile_size
    dst = np.empty_like(src_padded, dtype=out_dtype)

    inv_tw = 1.0 / tile_w
    inv_th = 1.0 / tile_h

    # Precompute X terms once (like OpenCV does)
    xa = np.empty(W, np.float32)
    xa1 = np.empty(W, np.float32)
    ind1 = np.empty(W, np.int32)
    ind2 = np.empty(W, np.int32)
    lut_stride = luts.shape[2]  # hist_size

    for x in range(W):
        txf = x * inv_tw - 0.5
        tx1 = math.floor(txf)
        tx2 = tx1 + 1
        frac = txf - tx1
        xa[x] = frac
        xa1[x] = 1.0 - frac
        tx1 = max(tx1, 0)
        tx2 = min(tx2, tiles_x - 1)
        ind1[x] = tx1 * lut_stride
        ind2[x] = tx2 * lut_stride

    for y in range(H):
        tyf = y * inv_th - 0.5
        ty1 = math.floor(tyf)
        ty2 = ty1 + 1
        ya = tyf - ty1
        ya1 = 1.0 - ya
        ty1 = max(ty1, 0)
        ty2 = min(ty2, tiles_y - 1)

        lutPlane1 = luts[ty1]  # shape: [tiles_x, hist_size]
        lutPlane2 = luts[ty2]

        src_row = src_padded[y]
        dst_row = dst[y]

        # vectorized over x is tricky due to per-pixel indexing; do a tight loop
        for x in range(W):
            val = int(src_row[x]) >> shift
            # indices inside LUT planes
            i1 = ind1[x] + val
            i2 = ind2[x] + val

            # bilinear interp over 4 LUTs
            r = (lutPlane1.flat[i1] * xa1[x] + lutPlane1.flat[i2] * xa[x]) * ya1 + \
                (lutPlane2.flat[i1] * xa1[x] + lutPlane2.flat[i2] * xa[x]) * ya

            # saturate + shift back
            if out_dtype == np.uint8:
                dst_row[x] = np.uint8(0 if r < 0 else 255 if r > 255 else int(r + 0.5))  # round & clamp
            else:
                # 16-bit domain before << shift
                r_i = 0 if r < 0 else (65535 >> shift) if r > (65535 >> shift) else int(r + 0.5)
                dst_row[x] = np.uint16(r_i << shift)

    return dst


def clahe_like_opencv(img, clip_limit_ui, tiles_x, tiles_y, shift):
    """
    Apply CLAHE to uint8 or uint16 single-channel image.
    - Matches OpenCV behavior: padding, clip-limit normalization, bilinear LUT interpolation.
    - 'shift' lets you down-bin (e.g., shift=4 for 12-bit bins on 16-bit image).
    """

    
    bitdepth =16
    bins = 1 << (bitdepth - shift)  # effective histogram size
    dtype = img.dtype
    print(dtype)
    # Pad to tile grid
    #later: i will need to add if statment to see if i need to use this def
    padded, (orig_h, orig_w) = pad_reflect_101(img, tiles_x, tiles_y)

    # Tile geometry
    H, W = padded.shape
    tile_h = H // tiles_y
    tile_w = W // tiles_x
    tile_area = tile_h * tile_w

    # OpenCV clip-limit conversion
    clip_count = clip_limit_to_count(clip_limit_ui, tile_area, bins)

    # LUT scale, matching OpenCV: (bins - 1) / tile_area
    lut_scale = float(bins - 1) / float(tile_area)

    # Build LUTs on the padded image
    luts, tile_size = compute_luts(padded, tiles_x, tiles_y, clip_count, bins, lut_scale, dtype)

    # Interpolate-apply on the padded image
    processed = interpolate_apply(padded, luts, tile_size, tiles_x, tiles_y, shift, dtype)

    # Crop back to original size
    return processed[:orig_h, :orig_w]


# -------------------------------------------
# PyAV: MKV -> CLAHE -> (PNG sequence or MKV)
# -------------------------------------------

def process_mkv_with_av(
    input_path,
    output_frames_dir="out_frames_16bit",          # if set, saves 16-bit PNGs here
    output_mkv="out_clahe_16bit.mkv",                 # if set, writes MKV video
    tiles_x=3,
    tiles_y=3,
    clip_limit_ui=120.0,
    shift=0,
    preserve_16bit=True,             # True -> process/keep 16-bit if available
    target_fps=None,                 # None -> use source fps
    codec_8bit='libx264',            # for 8-bit MKV
    codec_16bit='ffv1'               # for 16-bit MKV (lossless)
):
    """
    Reads MKV with PyAV, applies CLAHE, and writes either 16-bit PNGs or MKV.
    - If preserve_16bit is True, frames are decoded as gray16le; else gray(8-bit).
    - For MKV output:
        * 8-bit path uses H.264 for wide compatibility.
        * 16-bit path uses FFV1 (lossless) if available.
    """
    assert output_frames_dir or output_mkv, "Provide output_frames_dir and/or output_mkv."

    container = av.open(input_path)
    vstream = container.streams.video[0]
    # Prepare MKV writer if requested
    out_container = 1
    out_stream = 1
    out_w = vstream.width
    out_h = vstream.height

    if output_mkv:
        out_container = av.open(output_mkv, mode='w')

        # 16-bit lossless path (FFV1 supports gray16le in MKV)
        out_stream = out_container.add_stream(codec_16bit)
        out_stream.width = out_w
        out_stream.height = out_h
        # pix_fmt chosen from frames (gray16le) will guide encoder

    # Prepare PNG directory if requested
    if output_frames_dir:
        os.makedirs(output_frames_dir, exist_ok=True)

    frame_index = 0

    for frame in container.decode(video=0):
        # Decode to numpy gray
        img = frame.to_ndarray(format='gray16le').astype(np.uint16)
        

        # Apply CLAHE (matches OpenCV behavior closely)
        img_clahe = clahe_like_opencv(img, clip_limit_ui=clip_limit_ui,
                                      tiles_x=tiles_x, tiles_y=tiles_y, shift=shift)
        img_clahe_n=negative(img_clahe)
        img_clahe_n_m = cv2.medianBlur(img_clahe,3)
        # Write PNGs (16-bit preserved if dtype is uint16)
        if output_frames_dir:
            out_path = os.path.join(output_frames_dir, f"frame_{frame_index:06d}.png")
            cv2.imwrite(out_path, img_clahe_n_m)
        
        # Write MKV
        if out_container is not None:
            if img_clahe.dtype == np.uint16:
                vf = av.VideoFrame.from_ndarray(img_clahe_n_m, format='gray16le')
            else:
                vf = av.VideoFrame.from_ndarray(img_clahe_n_m, format='gray')
            for packet in out_stream.encode(vf):
                out_container.mux(packet)

        frame_index += 1


    container.close()




if __name__ == "__main__":
    # Example 1: 16-bit in/out (PNG sequence + 16-bit MKV with FFV1)
    FILE = "vids/Almesbar_face_20_08_2025_1.mkv"
    files = []
    for root, dirs, filenames in os.walk(folder_path):
        for filename in filenames:
            files.append(os.path.join(root, filename))
    for file in files
        process_mkv_with_av(input_path=file)

# %%
FILE = "vids/Almesbar_face_20_08_2025_1.mkv"

# %%
def negative(arr):
    """Return the negative of a numpy array (255 - value for 8-bit images)."""
    return np.abs(65535 - arr)

# %%
def show_freq(hist,msg):
    hist, bin_edges = np.histogram(img, bins=256, range=(0, 65536))

    plt.figure(figsize=(8, 4))
    plt.bar(bin_edges[:-1], hist, width=np.diff(bin_edges), edgecolor="black", align="edge")
    plt.xlabel("Pixel value (16-bit)")
    plt.ylabel("Frequency")
    plt.title(msg)
    plt.show()

# %%
def add_padding

# %%
def median_filter(img, kernal=3):
    padd_image=add_padding(img,kernal)
    H,W=img.shape()

    for x in range(H+1):
        for y+1 in range(W+kernal//2):
            h = x+kernal//2
            w = y+kernal//2
            padd_image[h,w]=median_of_kernal(padd_image[[x,y],[h+(h-x),w+(w-y)]],kernal)

# %%
def add_padding(img,kernal):
    kernal=kernal//2
    padded_image= np.pad(img, pad_width=kernal, mode='symmetric')

    return padd_image

# %%
def median_of_kernal(kernal,size):
    12323

# %%
import os
import math
import av
import numpy as np
import cv2
import threading
import queue
from concurrent.futures import ThreadPoolExecutor, as_completed
import time
from dataclasses import dataclass
from typing import Optional, Tuple

@dataclass
class FrameData:
    """Container for frame data and metadata"""
    index: int
    image: np.ndarray
    timestamp: Optional[float] = None

def negative(arr):
    """Return the negative of a numpy array (255 - value for 8-bit images)."""
    return np.abs(65535 - arr)

def pad_reflect_101(img, tiles_x, tiles_y):
    """Pad so H and W are divisible by tiles grid, like BORDER_REFLECT_101."""
    h, w = img.shape
    pad_y = (tiles_y - (h % tiles_y)) % tiles_y
    pad_x = (tiles_x - (w % tiles_x)) % tiles_x
    if pad_y or pad_x:
        img = np.pad(img, ((0, pad_y), (0, pad_x)), mode='reflect')
    return img, (h, w)

def clip_limit_to_count(clip_limit_ui, tile_area, hist_size):
    """OpenCV converts UI clipLimit to a per-tile count."""
    if clip_limit_ui <= 0.0:
        return 0
    count = int(clip_limit_ui * tile_area / hist_size)
    return max(count, 1)

def calc_tile_histogram(tile, hist_size, clip_count):
    """Histogram + clip + redistribute (like OpenCV's CPU path)."""
    hist, _ = np.histogram(tile, bins=hist_size, range=(0, hist_size))

    if clip_count > 0:
        excess = np.maximum(hist - clip_count, 0)
        clipped_total = int(excess.sum())
        hist = np.minimum(hist, clip_count)

        if clipped_total:
            redist_batch = clipped_total // hist_size
            hist += redist_batch
            residual = clipped_total - redist_batch * hist_size
    
            if residual > 0:
                step = max(1, hist_size // residual)
                for i in range(0, hist_size, step):
                    if residual <= 0:
                        break
                    hist[i] += 1
                    residual -= 1
    return hist

def lut_from_hist(hist, lut_scale, hist_size, dtype):
    """Cumulative sum with OpenCV-like rounding & clamp."""
    lut = np.rint(np.cumsum(hist) * lut_scale)
    return np.clip(lut, 0, hist_size - 1).astype(dtype)

def compute_luts_parallel(src_padded, tiles_x, tiles_y, clip_count, hist_size, lut_scale, dtype, num_threads=4):
    """Compute LUT per tile using parallel processing."""
    H, W = src_padded.shape
    tile_h = H // tiles_y
    tile_w = W // tiles_x
    luts = np.empty((tiles_y, tiles_x, hist_size), dtype=dtype)
    
    def process_tile(ty, tx):
        y0 = ty * tile_h
        y1 = y0 + tile_h
        x0 = tx * tile_w
        x1 = x0 + tile_w
        tile = src_padded[y0:y1, x0:x1]
        hist = calc_tile_histogram(tile, hist_size, clip_count)
        return ty, tx, lut_from_hist(hist, lut_scale, hist_size, dtype)
    
    with ThreadPoolExecutor(max_workers=num_threads) as executor:
        futures = []
        for ty in range(tiles_y):
            for tx in range(tiles_x):
                futures.append(executor.submit(process_tile, ty, tx))
        
        for future in as_completed(futures):
            ty, tx, lut = future.result()
            luts[ty, tx] = lut
    
    return luts, (tile_h, tile_w)

def interpolate_apply_vectorized(src_padded, luts, tile_size, tiles_x, tiles_y, shift, out_dtype):
    """Optimized bilinear interpolation using numpy vectorization where possible."""
    H, W = src_padded.shape
    tile_h, tile_w = tile_size
    dst = np.empty_like(src_padded, dtype=out_dtype)

    inv_tw = 1.0 / tile_w
    inv_th = 1.0 / tile_h

    # Precompute X terms
    x_coords = np.arange(W)
    txf = x_coords * inv_tw - 0.5
    tx1 = np.floor(txf).astype(np.int32)
    tx2 = tx1 + 1
    xa = txf - tx1
    xa1 = 1.0 - xa
    tx1 = np.clip(tx1, 0, tiles_x - 1)
    tx2 = np.clip(tx2, 0, tiles_x - 1)
    
    lut_stride = luts.shape[2]
    ind1 = tx1 * lut_stride
    ind2 = tx2 * lut_stride

    # Process rows in parallel
    def process_row(y):
        tyf = y * inv_th - 0.5
        ty1 = max(int(math.floor(tyf)), 0)
        ty2 = min(ty1 + 1, tiles_y - 1)
        ya = tyf - ty1
        ya1 = 1.0 - ya

        lutPlane1 = luts[ty1]
        lutPlane2 = luts[ty2]

        src_row = src_padded[y]
        dst_row = np.empty(W, dtype=out_dtype)

        for x in range(W):
            val = int(src_row[x]) >> shift
            i1 = ind1[x] + val
            i2 = ind2[x] + val

            r = (lutPlane1.flat[i1] * xa1[x] + lutPlane1.flat[i2] * xa[x]) * ya1 + \
                (lutPlane2.flat[i1] * xa1[x] + lutPlane2.flat[i2] * xa[x]) * ya

            if out_dtype == np.uint8:
                dst_row[x] = np.uint8(np.clip(r + 0.5, 0, 255))
            else:
                r_i = np.clip(r + 0.5, 0, 65535 >> shift).astype(np.int32)
                dst_row[x] = np.uint16(r_i << shift)
        
        return y, dst_row
    
    # Use thread pool for row processing
    with ThreadPoolExecutor(max_workers=4) as executor:
        futures = [executor.submit(process_row, y) for y in range(H)]
        for future in as_completed(futures):
            y, row = future.result()
            dst[y] = row

    return dst

def clahe_like_opencv_optimized(img, clip_limit_ui, tiles_x, tiles_y, shift, num_threads=4):
    """Optimized CLAHE with parallel processing."""
    bitdepth = 16
    bins = 1 << (bitdepth - shift)
    dtype = img.dtype
    
    padded, (orig_h, orig_w) = pad_reflect_101(img, tiles_x, tiles_y)
    H, W = padded.shape
    tile_h = H // tiles_y
    tile_w = W // tiles_x
    tile_area = tile_h * tile_w

    clip_count = clip_limit_to_count(clip_limit_ui, tile_area, bins)
    lut_scale = float(bins - 1) / float(tile_area)

    # Use parallel LUT computation
    luts, tile_size = compute_luts_parallel(padded, tiles_x, tiles_y, clip_count, 
                                           bins, lut_scale, dtype, num_threads)

    # Use optimized interpolation
    processed = interpolate_apply_vectorized(padded, luts, tile_size, tiles_x, tiles_y, shift, dtype)

    return processed[:orig_h, :orig_w]

class FrameProcessor:
    """Processes frames in a separate thread"""
    def __init__(self, clip_limit_ui, tiles_x, tiles_y, shift, num_threads=2):
        self.clip_limit_ui = clip_limit_ui
        self.tiles_x = tiles_x
        self.tiles_y = tiles_y
        self.shift = shift
        self.num_threads = num_threads
    
    def process_frame(self, frame_data: FrameData) -> FrameData:
        """Process a single frame"""
        img = frame_data.image
        
        # Apply CLAHE
        img_clahe = clahe_like_opencv_optimized(
            img, 
            clip_limit_ui=self.clip_limit_ui,
            tiles_x=self.tiles_x, 
            tiles_y=self.tiles_y, 
            shift=self.shift,
            num_threads=self.num_threads
        )
        
        # Stretch and process
        imin, imax = img.min(), img.max()
        if imax > imin:
            stretched = (img - imin) * (65535.0 / (imax - imin))
        else:
            stretched = img.copy()
        stretched = np.clip(stretched, 0, 65535).astype(np.uint16)
        stretched = negative(stretched)
        stretched = cv2.medianBlur(stretched, 3)
        
        img_clahe_n = negative(img_clahe)
        img_clahe_n_m = cv2.medianBlur(img_clahe_n, 3)
        
        # Stack horizontally
        result = np.hstack((img_clahe_n_m, stretched))
        
        return FrameData(index=frame_data.index, image=result, timestamp=frame_data.timestamp)

def process_mkv_with_av_threaded(
    input_path,
    output_frames_dir="out_frames_16bit",
    output_mkv="out_clahe_16bit.mkv",
    tiles_x=5,
    tiles_y=5,
    clip_limit_ui=120.0,
    shift=0,
    num_worker_threads=4,
    buffer_size=10,
    processing_threads_per_worker=2
):
    """
    Multithreaded MKV processing with parallel frame processing.
    
    Args:
        num_worker_threads: Number of threads for parallel frame processing
        buffer_size: Size of frame buffer for async processing
        processing_threads_per_worker: Threads used within each CLAHE computation
    """
    assert output_frames_dir or output_mkv, "Provide output_frames_dir and/or output_mkv."
    
    print(f"Processing {input_path} with {num_worker_threads} worker threads...")
    start_time = time.time()
    
    # Create output directory if needed
    if output_frames_dir:
        os.makedirs(output_frames_dir, exist_ok=True)
    
    # Open input container
    container = av.open(input_path)
    vstream = container.streams.video[0]
    
    # Prepare output container
    out_container = None
    out_stream = None
    if output_mkv:
        out_container = av.open(output_mkv, mode='w')
        out_stream = out_container.add_stream('ffv1')
        out_stream.width = vstream.width * 2  # Due to horizontal stacking
        out_stream.height = vstream.height
    
    # Create processor and queues
    processor = FrameProcessor(clip_limit_ui, tiles_x, tiles_y, shift, processing_threads_per_worker)
    input_queue = queue.Queue(maxsize=buffer_size)
    output_queue = queue.PriorityQueue(maxsize=buffer_size * 2)
    
    # Statistics
    frames_processed = 0
    frames_written = 0
    next_write_index = 0
    pending_frames = {}
    
    # Decoder thread
    def decode_frames():
        frame_index = 0
        try:
            for frame in container.decode(video=0):
                img = frame.to_ndarray(format='gray16le').astype(np.uint16)
                frame_data = FrameData(index=frame_index, image=img)
                input_queue.put(frame_data)
                frame_index += 1
        finally:
            # Signal end of stream
            for _ in range(num_worker_threads):
                input_queue.put(None)
    
    # Writer thread
    def write_frames():
        nonlocal frames_written, next_write_index
        
        while True:
            try:
                priority, frame_data = output_queue.get(timeout=1)
                
                if frame_data is None:
                    break
                
                # Store frame if not next in sequence
                if frame_data.index != next_write_index:
                    pending_frames[frame_data.index] = frame_data
                    continue
                
                # Write this frame and any pending sequential frames
                frames_to_write = [frame_data]
                next_write_index += 1
                
                while next_write_index in pending_frames:
                    frames_to_write.append(pending_frames.pop(next_write_index))
                    next_write_index += 1
                
                for fd in frames_to_write:
                    # Write PNG
                    if output_frames_dir:
                        out_path = os.path.join(output_frames_dir, f"frame_{fd.index:06d}.png")
                        cv2.imwrite(out_path, fd.image)
                    
                    # Write to video
                    if out_container:
                        vf = av.VideoFrame.from_ndarray(fd.image, format='gray16le')
                        for packet in out_stream.encode(vf):
                            out_container.mux(packet)
                    
                    frames_written += 1
                    
            except queue.Empty:
                continue
    
    # Start threads
    decode_thread = threading.Thread(target=decode_frames)
    write_thread = threading.Thread(target=write_frames)
    
    decode_thread.start()
    write_thread.start()
    
    # Process frames in parallel
    with ThreadPoolExecutor(max_workers=num_worker_threads) as executor:
        futures = []
        active_count = 0
        
        while True:
            try:
                frame_data = input_queue.get(timeout=0.1)
                
                if frame_data is None:
                    active_count += 1
                    if active_count >= num_worker_threads:
                        break
                    continue
                
                future = executor.submit(processor.process_frame, frame_data)
                futures.append(future)
                
                # Check completed futures
                done_futures = []
                for f in futures:
                    if f.done():
                        result = f.result()
                        output_queue.put((result.index, result))
                        done_futures.append(f)
                        frames_processed += 1
                        
                        if frames_processed % 100 == 0:
                            elapsed = time.time() - start_time
                            fps = frames_processed / elapsed
                            print(f"Processed {frames_processed} frames @ {fps:.2f} fps")
                
                # Remove completed futures
                for f in done_futures:
                    futures.remove(f)
                    
            except queue.Empty:
                continue
        
        # Wait for remaining futures
        for future in as_completed(futures):
            result = future.result()
            output_queue.put((result.index, result))
            frames_processed += 1
    
    # Signal writer to stop
    output_queue.put((-1, None))
    
    # Wait for threads to complete
    decode_thread.join()
    write_thread.join()
    
    # Flush and close
    if out_stream:
        for packet in out_stream.encode():
            out_container.mux(packet)
    
    container.close()
    if out_container:
        out_container.close()
    
    # Print statistics
    elapsed = time.time() - start_time
    print(f"\nCompleted processing {input_path}")
    print(f"Frames processed: {frames_processed}")
    print(f"Frames written: {frames_written}")
    print(f"Total time: {elapsed:.2f} seconds")
    print(f"Average FPS: {frames_processed / elapsed:.2f}")

def process_directory_parallel(directory="selection/", max_concurrent_videos=2):
    """Process multiple videos concurrently"""
    files = [f for f in os.listdir(directory) if os.path.isfile(os.path.join(directory, f))]
    
    with ThreadPoolExecutor(max_workers=max_concurrent_videos) as executor:
        futures = []
        for f in files:
            input_path = os.path.join(directory, f)
            output_dir = f"out_frames_16bit_{os.path.splitext(f)[0]}"
            output_mkv = f"out_{os.path.splitext(f)[0]}.mkv"
            
            future = executor.submit(
                process_mkv_with_av_threaded,
                input_path,
                output_dir,
                output_mkv,
                num_worker_threads=4,
                buffer_size=20,
                processing_threads_per_worker=2
            )
            futures.append((f, future))
        
        for filename, future in futures:
            try:
                future.result()
                print(f"Successfully processed {filename}")
            except Exception as e:
                print(f"Error processing {filename}: {e}")

if __name__ == "__main__":
    # Example 1: Process single file with multithreading
    FILE = "vids/Almesbar_face_20_08_2025_1.mkv"
    
    if os.path.exists(FILE):
        process_mkv_with_av_threaded(
            FILE,
            "out_frames_16bit",
            "out_clahe_16bit.mkv",
            num_worker_threads=6,  # Adjust based on CPU cores
            buffer_size=20,
            processing_threads_per_worker=2
        )
    
    # Example 2: Process directory with parallel video processing
    directory = "selection/"
    if os.path.exists(directory):
        process_directory_parallel(directory, max_concurrent_videos=2)

# %%
import os
import math
import av
import numpy as np
import cv2
def negative(arr):
    """Return the negative of a numpy array (255 - value for 8-bit images)."""
    return np.abs(65535 - arr)

def pad_reflect_101(img, tiles_x, tiles_y):
    """Pad so H and W are divisible by tiles grid, like BORDER_REFLECT_101."""
    h, w = img.shape
    pad_y = (tiles_y - (h % tiles_y))
    pad_x = (tiles_x - (w % tiles_x)) 
    if pad_y or pad_x:
        img = np.pad(img, ((0, pad_y), (0, pad_x)), mode='reflect')
    return img, (h, w)  # keep original size to crop back later


def clip_limit_to_count(clip_limit_ui, tile_area, hist_size):
    """OpenCV converts UI clipLimit to a per-tile count."""
    if clip_limit_ui <= 0.0:
        return 0
    count = int(clip_limit_ui * tile_area / hist_size)
    return max(count, 1)


def calc_tile_histogram(tile, hist_size, clip_count):
    """Histogram + clip + redistribute (like OpenCV's CPU path)."""
    # Fast histogram
    hist, _ = np.histogram(tile, bins=hist_size, range=(0, hist_size))

    if clip_count > 0:

        excess = np.maximum(hist - clip_count, 0)
        clipped_total = int(excess.sum())
        # clip
        hist = np.minimum(hist, clip_count)

        if clipped_total:
            # even batch
            redist_batch = clipped_total // hist_size
            hist += redist_batch
            # remainder spread
            residual = clipped_total - redist_batch * hist_size
    
            if residual > 0:
                step = max(1, hist_size // residual)
                # increment roughly uniformly
                for i in range(0, hist_size, step):
                    if residual <= 0:
                        break
                    hist[i] += 1
                    residual -= 1
    return hist


def lut_from_hist(hist, lut_scale, hist_size, dtype):
    """Cumulative sum with OpenCV-like rounding & clamp."""
    lut = np.rint(np.cumsum(hist) * lut_scale)  # round-to-nearest
    return np.clip(lut, 0, hist_size - 1).astype(dtype)


def compute_luts(src_padded, tiles_x, tiles_y, clip_count, hist_size, lut_scale, dtype):
    """Compute LUT per tile on the padded image."""
    H, W = src_padded.shape
    tile_h = H // tiles_y
    tile_w = W // tiles_x
    luts = np.empty((tiles_y, tiles_x, hist_size), dtype=dtype)

    for ty in range(tiles_y):
        y0 = ty * tile_h
        y1 = y0 + tile_h
        for tx in range(tiles_x):
            x0 = tx * tile_w
            x1 = x0 + tile_w
            tile = src_padded[y0:y1, x0:x1]
            hist = calc_tile_histogram(tile, hist_size, clip_count)
            luts[ty, tx] = lut_from_hist(hist, lut_scale, hist_size, dtype)
    return luts, (tile_h, tile_w)


def interpolate_apply(src_padded, luts, tile_size, tiles_x, tiles_y, shift, out_dtype):
    """Bilinear interpolation of 4 neighboring tile LUTs, like OpenCV."""
    H, W = src_padded.shape
    tile_h, tile_w = tile_size
    dst = np.empty_like(src_padded, dtype=out_dtype)

    inv_tw = 1.0 / tile_w
    inv_th = 1.0 / tile_h

    # Precompute X terms once (like OpenCV does)
    xa = np.empty(W, np.float32)
    xa1 = np.empty(W, np.float32)
    ind1 = np.empty(W, np.int32)
    ind2 = np.empty(W, np.int32)
    lut_stride = luts.shape[2]  # hist_size

    for x in range(W):
        txf = x * inv_tw - 0.5
        tx1 = math.floor(txf)
        tx2 = tx1 + 1
        frac = txf - tx1
        xa[x] = frac
        xa1[x] = 1.0 - frac
        tx1 = max(tx1, 0)
        tx2 = min(tx2, tiles_x - 1)
        ind1[x] = tx1 * lut_stride
        ind2[x] = tx2 * lut_stride

    for y in range(H):
        tyf = y * inv_th - 0.5
        ty1 = math.floor(tyf)
        ty2 = ty1 + 1
        ya = tyf - ty1
        ya1 = 1.0 - ya
        ty1 = max(ty1, 0)
        ty2 = min(ty2, tiles_y - 1)

        lutPlane1 = luts[ty1]  # shape: [tiles_x, hist_size]
        lutPlane2 = luts[ty2]

        src_row = src_padded[y]
        dst_row = dst[y]

        # vectorized over x is tricky due to per-pixel indexing; do a tight loop
        for x in range(W):
            val = int(src_row[x]) >> shift
            # indices inside LUT planes
            i1 = ind1[x] + val
            i2 = ind2[x] + val

            # bilinear interp over 4 LUTs
            r = (lutPlane1.flat[i1] * xa1[x] + lutPlane1.flat[i2] * xa[x]) * ya1 + \
                (lutPlane2.flat[i1] * xa1[x] + lutPlane2.flat[i2] * xa[x]) * ya

            # saturate + shift back
            if out_dtype == np.uint8:
                dst_row[x] = np.uint8(0 if r < 0 else 255 if r > 255 else int(r + 0.5))  # round & clamp
            else:
                # 16-bit domain before << shift
                r_i = 0 if r < 0 else (65535 >> shift) if r > (65535 >> shift) else int(r + 0.5)
                dst_row[x] = np.uint16(r_i << shift)

    return dst


def clahe_like_opencv(img, clip_limit_ui, tiles_x, tiles_y, shift):
    """
    Apply CLAHE to uint8 or uint16 single-channel image.
    - Matches OpenCV behavior: padding, clip-limit normalization, bilinear LUT interpolation.
    - 'shift' lets you down-bin (e.g., shift=4 for 12-bit bins on 16-bit image).
    """

    
    bitdepth =16
    bins = 1 << (bitdepth - shift)  # effective histogram size
    dtype = img.dtype
    print(dtype)
    # Pad to tile grid
    #later: i will need to add if statment to see if i need to use this def
    padded, (orig_h, orig_w) = pad_reflect_101(img, tiles_x, tiles_y)

    # Tile geometry
    H, W = padded.shape
    tile_h = H // tiles_y
    tile_w = W // tiles_x
    tile_area = tile_h * tile_w

    # OpenCV clip-limit conversion
    clip_count = clip_limit_to_count(clip_limit_ui, tile_area, bins)

    # LUT scale, matching OpenCV: (bins - 1) / tile_area
    lut_scale = float(bins - 1) / float(tile_area)

    # Build LUTs on the padded image
    luts, tile_size = compute_luts(padded, tiles_x, tiles_y, clip_count, bins, lut_scale, dtype)

    # Interpolate-apply on the padded image
    processed = interpolate_apply(padded, luts, tile_size, tiles_x, tiles_y, shift, dtype)

    # Crop back to original size
    return processed[:orig_h, :orig_w]


# -------------------------------------------
# PyAV: MKV -> CLAHE -> (PNG sequence or MKV)
# -------------------------------------------

def process_mkv_with_av(
    input_path,
    output_frames_dir="out_frames_16bit",          # if set, saves 16-bit PNGs here
    output_mkv="out_clahe_16bit.mkv",                 # if set, writes MKV video
    tiles_x=5,
    tiles_y=5,
    clip_limit_ui=120.0,
    shift=0,
    preserve_16bit=True,             # True -> process/keep 16-bit if available
    target_fps=None,                 # None -> use source fps
    codec_8bit='libx264',            # for 8-bit MKV
    codec_16bit='ffv1'               # for 16-bit MKV (lossless)
):
    """
    Reads MKV with PyAV, applies CLAHE, and writes either 16-bit PNGs or MKV.
    - If preserve_16bit is True, frames are decoded as gray16le; else gray(8-bit).
    - For MKV output:
        * 8-bit path uses H.264 for wide compatibility.
        * 16-bit path uses FFV1 (lossless) if available.
    """
    assert output_frames_dir or output_mkv, "Provide output_frames_dir and/or output_mkv."

    container = av.open(input_path)
    vstream = container.streams.video[0]
    # Prepare MKV writer if requested
    out_container = 1
    out_stream = 1
    out_w = vstream.width*2
    out_h = vstream.height

    if output_mkv:
        out_container = av.open(output_mkv, mode='w')

        # 16-bit lossless path (FFV1 supports gray16le in MKV)
        out_stream = out_container.add_stream(codec_16bit)
        out_stream.width = out_w
        out_stream.height = out_h
        # pix_fmt chosen from frames (gray16le) will guide encoder

    # Prepare PNG directory if requested
    if output_frames_dir:
        os.makedirs(output_frames_dir, exist_ok=True)

    frame_index = 0

    for frame in container.decode(video=0):
        # Decode to numpy gray
        img = frame.to_ndarray(format='gray16le').astype(np.uint16)
        n=11
        left = img[:, :n]
        right = img[:, n:]
        
        # Concatenate: first the right part, then the left part
        img = np.hstack([right, left])

        # Apply CLAHE (matches OpenCV behavior closely)
        arr1d = img.flatten()
        arr1d = np.sort(arr1d)
        img_clahe = clahe_like_opencv(img, clip_limit_ui=clip_limit_ui,
                                      tiles_x=tiles_x, tiles_y=tiles_y, shift=shift)
        imin = arr1d[1000]
        imax= arr1d[306199]
       #imin, imax = img.min(), img.max()
        stretched = (img - imin) * (65535.0 / (imax - imin))
        stretched = np.clip(stretched, 0, 65535).astype(np.uint16)
        stretched = negative(stretched)
        stretched = cv2.medianBlur(stretched,3)
        # n=12
        # left = stretched[:, :n]
        # right = stretched[:, n:]
        
        # # Concatenate: first the right part, then the left part
        # stretched = np.hstack([right, left])
        img_clahe_n=negative(img_clahe)
        img_clahe_n_m = cv2.medianBlur(img_clahe_n,3)
        # n=12
        # left = img_clahe_n_m[:, :n]
        # right = img_clahe_n_m[:, n:]
        
        # # Concatenate: first the right part, then the left part
        # img_clahe_n_m = np.hstack([right, left])
        # Write PNGs (16-bit preserved if dtype is uint16)
        img_clahe_n_m = np.hstack((img_clahe_n_m,stretched))
        if True:
            out_path = os.path.join(output_frames_dir, f"frame_{frame_index:06d}.png")
            cv2.imwrite(out_path, img_clahe_n_m)
        
        if out_container is not None:
            if img_clahe.dtype == np.uint16:
                vf = av.VideoFrame.from_ndarray(img_clahe_n_m, format='gray16le')
            for packet in out_stream.encode(vf):
                out_container.mux(packet)

        frame_index += 1


    container.close()




if __name__ == "__main__":
    # Example 1: 16-bit in/out (PNG sequence + 16-bit MKV with FFV1)
    FILE = "vids/Almesbar_face_20_08_2025_1.mkv"
    directory = "selection/"
    
    # list all files in the directory
    files = os.listdir(directory)
    
    # filter out only files (exclude folders)
    files = [f for f in files if os.path.isfile(os.path.join(directory, f))]
    
    # print them
    for f in files:
        process_mkv_with_av(f"selection/{f}","out_frames_16bit",f)
# Out:
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
# uint16
